# %%
import pickle

# Ruta al archivo pickle (asegúrate de usar la ruta correcta)
model_path = "/Users/pauladeleon/Desktop/modelos/rf_model.pkl"

# Cargar el modelo
with open(model_path, "rb") as file:
    model = pickle.load(file)
